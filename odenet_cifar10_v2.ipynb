# %% [markdown]
# #### This programming modifies the code named 'odenet_mnist.py',which is the source code from paper Ricky T.Q. Chen et al. 2018, 'Neural Ordinary Differential Equations.

# %% [markdown]
# #### Change points
# ##### 1. Change the dataset from MNIST to CIFAR10

# %% [markdown]
# start edit date: 12/11/2020
#
# last edite date: 5/11/2020

# %%
# copy the same reqiured libraries
import os
import argparse
import logging
import time
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torchvision.datasets as datasets
import torchvision.transforms as transforms

# %%
# copy the some basic neural network modules
def conv3x3(in_planes, out_planes, stride=1):
    """3x3 convolution with padding"""
    return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride, padding=1, bias=False)


def conv1x1(in_planes, out_planes, stride=1):
    """1x1 convolution"""
    return nn.Conv2d(in_planes, out_planes, kernel_size=1, stride=stride, bias=False)


def norm(dim):
    return nn.GroupNorm(min(32, dim), dim)

class ResBlock(nn.Module):
    expansion = 1

    def __init__(self, inplanes, planes, stride=1, downsample=None):
        super(ResBlock, self).__init__()
        self.norm1 = norm(inplanes)
        self.relu = nn.ReLU(inplace=True)
        self.downsample = downsample
        self.conv1 = conv3x3(inplanes, planes, stride)
        self.norm2 = norm(planes)
        self.conv2 = conv3x3(planes, planes)

    def forward(self, x):
        shortcut = x

        out = self.relu(self.norm1(x))

        if self.downsample is not None:
            shortcut = self.downsample(out)

        out = self.conv1(out)
        out = self.norm2(out)
        out = self.relu(out)
        out = self.conv2(out)

        return out + shortcut


class ConcatConv2d(nn.Module):

    def __init__(self, dim_in, dim_out, ksize=3, stride=1, padding=0, dilation=1, groups=1, bias=False, transpose=False):
        super(ConcatConv2d, self).__init__()
        module = nn.ConvTranspose2d if transpose else nn.Conv2d
        self._layer = module(
            dim_in + 1, dim_out, kernel_size=ksize, stride=stride, padding=padding, dilation=dilation, groups=groups,
            bias=bias
        )          # add another dimension for time

    def forward(self, t, x):
        tt = torch.ones_like(x[:, :1, :, :]) * t #fill the tensor with all 1, dimension as similar as x[:,:1,:,:]
        ttx = torch.cat([tt, x], 1)              #concatenate time with x, at dimension 1. 
        return self._layer(ttx)


class ODEfunc(nn.Module): # The ODE function

    def __init__(self, dim):
        super(ODEfunc, self).__init__()
        #self.norm1 = norm(dim)
        #self.relu = nn.ReLU(inplace=True)
        self.conv1 = ConcatConv2d(dim, dim, 3, 1, 1) #(6-3+2*1)/1+1 = 6
        #self.norm2 = norm(dim)
        #self.conv2 = ConcatConv2d(dim, dim, 3, 1, 1) #(6-3+2*1)/1+1 = 6
        #self.norm3 = norm(dim)
        self.nfe = 0

    def forward(self, t, x):
        self.nfe += 1
        #out = self.norm1(x)
        #out = self.relu(out)
        out = self.conv1(t, x)
        #out = self.norm2(out)
        #out = self.relu(out)
        #out = self.conv2(t, out)
        #out = self.norm3(out)
        return out


class ODEBlock(nn.Module):

    def __init__(self, odefunc):
        super(ODEBlock, self).__init__()
        self.odefunc = odefunc
        self.integration_time = torch.tensor([0, 1]).float()

    def forward(self, x):
        #print(x.shape)
        self.integration_time = self.integration_time.type_as(x)
        #out = odeint(self.odefunc, x, self.integration_time, rtol=args.tol, atol=args.tol)
        #out = odeint(self.odefunc, x, self.integration_time, rtol=tol, atol=tol)
        out = odeint(self.odefunc, x, self.integration_time, rtol=tol, atol=tol,method = 'euler', 
                     options=dict(step_size=0.05))
        return out[1]

    @property
    def nfe(self):
        return self.odefunc.nfe

    @nfe.setter
    def nfe(self, value):
        self.odefunc.nfe = value


class Flatten(nn.Module):

    def __init__(self):
        super(Flatten, self).__init__()

    def forward(self, x):
        #print(x.shape) # 128*64*1*1
        shape = torch.prod(torch.tensor(x.shape[1:])).item()
        return x.view(-1, shape)

# %%
class RunningAverageMeter(object):
    """Computes and stores the average and current value"""

    def __init__(self, momentum=0.99):
        self.momentum = momentum
        self.reset()

    def reset(self):
        self.val = None
        self.avg = 0

    def update(self, val):
        if self.val is None:
            self.avg = val
        else:
            self.avg = self.avg * self.momentum + val * (1 - self.momentum)
        self.val = val


def get_mnist_loaders(data_aug=False, batch_size=128, test_batch_size=1000, perc=1.0):
    normalize = transforms.Normalize(mean=[0.491, 0.482, 0.447], std=[0.247, 0.243, 0.262])
    if data_aug:
        transform_train = transforms.Compose([
            transforms.RandomCrop(32, padding=4),  # for cifar-10 change 28 to 32, to match the dimension
            transforms.ToTensor(),
            normalize,
        ])
    else:
        transform_train = transforms.Compose([
            transforms.ToTensor(),
            normalize,
        ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    train_loader = DataLoader(
        datasets.CIFAR10(root='.data/cifar10', train=True, download=True, transform=transform_train), batch_size=batch_size,
        shuffle=True, num_workers=2, drop_last=True
    )   # DataLoader returns an iterable over the dataset

    train_eval_loader = DataLoader(
        datasets.CIFAR10(root='.data/cifar10', train=True, download=True, transform=transform_test),
        batch_size=test_batch_size, shuffle=False, num_workers=2, drop_last=True
    )

    test_loader = DataLoader(
        datasets.CIFAR10(root='.data/cifar10', train=False, download=True, transform=transform_test),
        batch_size=test_batch_size, shuffle=False, num_workers=2, drop_last=True
    )

    return train_loader, test_loader, train_eval_loader


def inf_generator(iterable):
    """Allows training with DataLoaders in a single infinite loop:
        for i, (x, y) in enumerate(inf_generator(train_loader)):
    """
    iterator = iterable.__iter__()
    while True:
        try:
            yield iterator.__next__()
        except StopIteration:
            iterator = iterable.__iter__()


def learning_rate_with_decay(batch_size, batch_denom, batches_per_epoch, boundary_epochs, decay_rates):
    #initial_learning_rate = args.lr * batch_size / batch_denom
    initial_learning_rate = lr * batch_size / batch_denom

    boundaries = [int(batches_per_epoch * epoch) for epoch in boundary_epochs]
    vals = [initial_learning_rate * decay for decay in decay_rates]

    def learning_rate_fn(itr):
        lt = [itr < b for b in boundaries] + [True]
        i = np.argmax(lt)
        return vals[i]

    return learning_rate_fn

def one_hot(x, K):
    return np.array(x[:, None] == np.arange(K)[None, :], dtype=int)


def accuracy(model, dataset_loader):
    total_correct = 0
    for x, y in dataset_loader:
        x = x.to(device)
        y = one_hot(np.array(y.numpy()), 10)

        target_class = np.argmax(y, axis=1)
        predicted_class = np.argmax(model(x).cpu().detach().numpy(), axis=1)
        total_correct += np.sum(predicted_class == target_class)
    return total_correct / len(dataset_loader.dataset)


def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


def makedirs(dirname):
    if not os.path.exists(dirname):
        os.makedirs(dirname)


def get_logger(logpath, filepath, package_files=[], displaying=True, saving=True, debug=False):
    logger = logging.getLogger()  # 1. setup a logger
    if debug:
        level = logging.DEBUG
    else:
        level = logging.INFO
    logger.setLevel(level)     # 2. define the cut-point of level, logger levels have default priority 
    if saving:
        info_file_handler = logging.FileHandler(logpath, mode="a")
        info_file_handler.setLevel(level)
        logger.addHandler(info_file_handler)
    if displaying:
        console_handler = logging.StreamHandler()
        console_handler.setLevel(level)
        logger.addHandler(console_handler)
    logger.info(filepath)
    with open(filepath, "r") as f:
        logger.info(f.read())

    for f in package_files:
        logger.info(f)
        with open(f, "r") as package_f:
            logger.info(package_f.read())

    return logger

# %%
# the arguments change argparse to variables
#parser = argparse.ArgumentParser()
#parser.add_argument('--network', type=str, choices=['resnet', 'odenet'], default='odenet')
#network = 'odenet'
network = 'resnet'
#parser.add_argument('--tol', type=float, default=1e-3)
tol = 1e-3
#parser.add_argument('--adjoint', type=eval, default=False, choices=[True, False])
adjoint = False
#parser.add_argument('--downsampling-method', type=str, default='conv', choices=['conv', 'res'])
downsampling_method = 'conv'
#parser.add_argument('--nepochs', type=int, default=160)
nepochs = 160
#parser.add_argument('--data_aug', type=eval, default=True, choices=[True, False])
data_aug = True
#parser.add_argument('--lr', type=float, default=0.1)
lr = 0.1
#parser.add_argument('--batch_size', type=int, default=128)
batch_size = 128
#parser.add_argument('--test_batch_size', type=int, default=1000)
test_batch_size = 1000
#parser.add_argument('--save', type=str, default='./experiment1')
save = './NeuralODE_CIFAR10_experiment/NeuralODE_CIFAR10_downsampling/'
#parser.add_argument('--debug', action='store_true')
debug = False
#parser.add_argument('--gpu', type=int, default=0)
gpu = 1
#args = parser.parse_args()

# %%
#if __name__ == '__main__':
if adjoint:
    from torchdiffeq import odeint_adjoint as odeint
else:
    from torchdiffeq import odeint
#makedirs(args.save)
if not os.path.exists(save):
        os.makedirs(save)
#logger = get_logger(logpath=os.path.join(args.save, 'logs'), filepath=os.path.abspath(__file__))
#logger.info(args)
logger = get_logger(logpath=os.path.join(save, 'logs'), filepath=os.path.abspath('/bigdata1/proj/yduo/ODEnet/test.txt'))
#device = torch.device('cuda:' + str(args.gpu) if torch.cuda.is_available() else 'cpu')
device = torch.device('cuda:' + str(gpu) if torch.cuda.is_available() else 'cpu')
#is_odenet = args.network == 'odenet'
is_odenet = network == 'odenet'


#if args.downsampling_method == 'conv':
if downsampling_method == 'conv':
    downsampling_layers = [
        nn.Conv2d(3, 64, 3, 1), #(28-3)/1+1 = 26
        norm(64),
        nn.ReLU(inplace=True),
        nn.Conv2d(64, 64, 4, 2, 1),#(26-4+2*1)/2+1 =13
        norm(64),
        nn.ReLU(inplace=True),
        nn.Conv2d(64, 64, 4, 2, 1),#(13-4+2*1)/2+1= 6
        #norm(64),
        #nn.ReLU(inplace=True),
        #nn.Conv2d(64, 64, 3, 1, 1, bias=False),#(26-4+2*1)/2+1 =13
       
    ]
#elif args.downsampling_method == 'res':
elif downsampling_method == 'res':
    downsampling_layers = [
        nn.Conv2d(1, 64, 3, 1),
        ResBlock(64, 64, stride=2, downsample=conv1x1(64, 64, 2)),
        ResBlock(64, 64, stride=2, downsample=conv1x1(64, 64, 2)),
    ]

feature_layers = [ODEBlock(ODEfunc(64))] if is_odenet else [ResBlock(64, 64) for _ in range(50)]
fc_layers = [norm(64), nn.ReLU(inplace=True), nn.AdaptiveAvgPool2d((1, 1)), Flatten(), nn.Linear(64, 10)]

model = nn.Sequential(*downsampling_layers, *feature_layers, *fc_layers).to(device)
#model = nn.Sequential(*downsampling_layers,  *fc_layers).to(device)
logger.info(model)
logger.info('Number of parameters: {}'.format(count_parameters(model)))

criterion = nn.CrossEntropyLoss().to(device)

#train_loader, test_loader, train_eval_loader = get_mnist_loaders(
#    args.data_aug, args.batch_size, args.test_batch_size
#)
train_loader, test_loader, train_eval_loader = get_mnist_loaders(
    data_aug, batch_size, test_batch_size
)

data_gen = inf_generator(train_loader)
batches_per_epoch = len(train_loader)

#lr_fn = learning_rate_with_decay(
#    args.batch_size, batch_denom=128, batches_per_epoch=batches_per_epoch, boundary_epochs=[60, 100, 140],
#    decay_rates=[1, 0.1, 0.01, 0.001]
#)
lr_fn = learning_rate_with_decay(
    batch_size, batch_denom=128, batches_per_epoch=batches_per_epoch, boundary_epochs=[60, 100, 140],
    decay_rates=[1, 0.1, 0.01, 0.001]
)

#optimizer = torch.optim.SGD(model.parameters(), lr=args.lr, momentum=0.9)
optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9)


best_acc = 0
batch_time_meter = RunningAverageMeter()
f_nfe_meter = RunningAverageMeter()
b_nfe_meter = RunningAverageMeter()
end = time.time()

#for itr in range(args.nepochs * batches_per_epoch):
for itr in range(nepochs * batches_per_epoch):

    for param_group in optimizer.param_groups:
        param_group['lr'] = lr_fn(itr)

    optimizer.zero_grad()
    x, y = data_gen.__next__()
    x = x.to(device)  # 128*1*28*28
    # print(x.shape)
    y = y.to(device)
    #print(len(torch.unique(y)))
    logits = model(x)
    loss = criterion(logits, y)

    if is_odenet:
        nfe_forward = feature_layers[0].nfe
        feature_layers[0].nfe = 0

    loss.backward()
    optimizer.step()

    if is_odenet:
        nfe_backward = feature_layers[0].nfe
        feature_layers[0].nfe = 0

    batch_time_meter.update(time.time() - end)
    if is_odenet:
        f_nfe_meter.update(nfe_forward)
        b_nfe_meter.update(nfe_backward)
    end = time.time()

    if itr % batches_per_epoch == 0:
        with torch.no_grad():
            train_acc = accuracy(model, train_eval_loader)
            val_acc = accuracy(model, test_loader)
            if val_acc > best_acc:
                #torch.save({'state_dict': model.state_dict(), 'args': args}, os.path.join(args.save, 'model.pth'))
                torch.save({'state_dict': model.state_dict()}, os.path.join(save, 'model.pth'))
                best_acc = val_acc
            logger.info(
                "Epoch {:04d} | Time {:.3f} ({:.3f}) | NFE-F {:.1f} | NFE-B {:.1f} | "
                "Train Acc {:.4f} | Test Acc {:.4f}".format(
                    itr // batches_per_epoch, batch_time_meter.val, batch_time_meter.avg, f_nfe_meter.avg,
                    b_nfe_meter.avg, train_acc, val_acc
                )
            )
# Out:
# /bigdata1/proj/yduo/ODEnet/test.txt
#
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1))
#   (1): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (2): ReLU(inplace=True)
#   (3): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (4): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (5): ReLU(inplace=True)
#   (6): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (7): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (8): ReLU(inplace=True)
#   (9): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (10): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (11): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (12): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (13): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (14): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (15): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (16): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (17): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (18): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (19): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (20): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (21): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (22): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (23): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (24): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (25): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (26): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (27): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (28): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (29): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (30): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (31): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (32): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (33): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (34): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (35): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (36): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (37): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (38): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (39): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (40): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (41): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (42): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (43): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (44): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (45): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (46): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (47): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (48): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (49): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (50): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (51): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (52): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (53): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (54): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (55): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (56): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (57): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (58): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (59): ResBlock(
#     (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (60): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (61): ReLU(inplace=True)
#   (62): AdaptiveAvgPool2d(output_size=(1, 1))
#   (63): Flatten()
#   (64): Linear(in_features=64, out_features=10, bias=True)
# )
# Number of parameters: 3870218
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0000 | Time 0.315 (0.315) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.0958 | Test Acc 0.0995
# Epoch 0001 | Time 0.337 (0.063) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.3961 | Test Acc 0.4026
# Epoch 0002 | Time 0.360 (0.060) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.4964 | Test Acc 0.4929
# Epoch 0003 | Time 0.404 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.5588 | Test Acc 0.5503
# Epoch 0004 | Time 0.399 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.6220 | Test Acc 0.6136
# Epoch 0005 | Time 0.322 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.6726 | Test Acc 0.6531
# Epoch 0006 | Time 0.328 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.7076 | Test Acc 0.6830
# Epoch 0007 | Time 0.337 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.7382 | Test Acc 0.7065
# Epoch 0008 | Time 0.331 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.7608 | Test Acc 0.7342
# Epoch 0009 | Time 0.374 (0.060) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.7731 | Test Acc 0.7373
# Epoch 0010 | Time 0.320 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.7488 | Test Acc 0.7212
# Epoch 0011 | Time 0.318 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.8191 | Test Acc 0.7711
# Epoch 0012 | Time 0.389 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.8322 | Test Acc 0.7796
# Epoch 0013 | Time 0.350 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.8289 | Test Acc 0.7768
# Epoch 0014 | Time 0.318 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.8475 | Test Acc 0.7911
# Epoch 0015 | Time 0.347 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.8715 | Test Acc 0.8114
# Epoch 0016 | Time 0.328 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.8848 | Test Acc 0.8168
# Epoch 0017 | Time 0.335 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.8836 | Test Acc 0.8129
# Epoch 0018 | Time 0.402 (0.060) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.8978 | Test Acc 0.8167
# Epoch 0019 | Time 0.322 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.8947 | Test Acc 0.8095
# Epoch 0020 | Time 0.331 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9003 | Test Acc 0.8145
# Epoch 0021 | Time 0.330 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9166 | Test Acc 0.8208
# Epoch 0022 | Time 0.346 (0.060) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9224 | Test Acc 0.8303
# Epoch 0023 | Time 0.350 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9202 | Test Acc 0.8295
# Epoch 0024 | Time 0.323 (0.061) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9195 | Test Acc 0.8211
# Epoch 0025 | Time 0.340 (0.060) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9342 | Test Acc 0.8311
# Epoch 0026 | Time 0.363 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9448 | Test Acc 0.8382
# Epoch 0027 | Time 0.331 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9377 | Test Acc 0.8360
# Epoch 0028 | Time 0.338 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9423 | Test Acc 0.8289
# Epoch 0029 | Time 0.342 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9529 | Test Acc 0.8344
# Epoch 0030 | Time 0.400 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9537 | Test Acc 0.8309
# Epoch 0031 | Time 0.323 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9661 | Test Acc 0.8453
# Epoch 0032 | Time 0.337 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9618 | Test Acc 0.8360
# Epoch 0033 | Time 0.352 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9537 | Test Acc 0.8292
# Epoch 0034 | Time 0.331 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9664 | Test Acc 0.8365
# Epoch 0035 | Time 0.315 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9678 | Test Acc 0.8391
# Epoch 0036 | Time 0.351 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9618 | Test Acc 0.8354
# Epoch 0037 | Time 0.331 (0.061) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9670 | Test Acc 0.8336
# Epoch 0038 | Time 0.385 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9772 | Test Acc 0.8471
# Epoch 0039 | Time 0.323 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9717 | Test Acc 0.8341
# Epoch 0040 | Time 0.327 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9669 | Test Acc 0.8333
# Epoch 0041 | Time 0.376 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9750 | Test Acc 0.8376
# Epoch 0042 | Time 0.347 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9711 | Test Acc 0.8307
# Epoch 0043 | Time 0.327 (0.062) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9758 | Test Acc 0.8314
# Epoch 0044 | Time 0.324 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9832 | Test Acc 0.8406
# Epoch 0045 | Time 0.310 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9727 | Test Acc 0.8313
# Epoch 0046 | Time 0.336 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9850 | Test Acc 0.8433
# Epoch 0047 | Time 0.315 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9871 | Test Acc 0.8504
# Epoch 0048 | Time 0.356 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9874 | Test Acc 0.8485
# Epoch 0049 | Time 0.322 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9858 | Test Acc 0.8443
# Epoch 0050 | Time 0.325 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9872 | Test Acc 0.8458
# Epoch 0051 | Time 0.331 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9909 | Test Acc 0.8514
# Epoch 0052 | Time 0.368 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9913 | Test Acc 0.8476
# Epoch 0053 | Time 0.329 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9882 | Test Acc 0.8428
# Epoch 0054 | Time 0.363 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9833 | Test Acc 0.8409
# Epoch 0055 | Time 0.323 (0.061) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9880 | Test Acc 0.8452
# Epoch 0056 | Time 0.351 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9922 | Test Acc 0.8491
# Epoch 0057 | Time 0.327 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9902 | Test Acc 0.8455
# Epoch 0058 | Time 0.322 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9868 | Test Acc 0.8403
# Epoch 0059 | Time 0.311 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9911 | Test Acc 0.8447
# Epoch 0060 | Time 0.352 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9860 | Test Acc 0.8399
# Epoch 0061 | Time 0.413 (0.060) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9982 | Test Acc 0.8586
# Epoch 0062 | Time 0.316 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9987 | Test Acc 0.8598
# Epoch 0063 | Time 0.359 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9990 | Test Acc 0.8598
# Epoch 0064 | Time 0.328 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9991 | Test Acc 0.8615
# Epoch 0065 | Time 0.324 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9992 | Test Acc 0.8612
# Epoch 0066 | Time 0.330 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9994 | Test Acc 0.8626
# Epoch 0067 | Time 0.320 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9994 | Test Acc 0.8638
# Epoch 0068 | Time 0.326 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9995 | Test Acc 0.8621
# Epoch 0069 | Time 0.315 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9995 | Test Acc 0.8639
# Epoch 0070 | Time 0.316 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9996 | Test Acc 0.8633
# Epoch 0071 | Time 0.315 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9996 | Test Acc 0.8634
# Epoch 0072 | Time 0.321 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9996 | Test Acc 0.8653
# Epoch 0073 | Time 0.359 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9997 | Test Acc 0.8649
# Epoch 0074 | Time 0.314 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9996 | Test Acc 0.8645
# Epoch 0075 | Time 0.332 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9997 | Test Acc 0.8653
# Epoch 0076 | Time 0.331 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9996 | Test Acc 0.8646
# Epoch 0077 | Time 0.360 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9997 | Test Acc 0.8648
# Epoch 0078 | Time 0.332 (0.061) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8651
# Epoch 0079 | Time 0.316 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9997 | Test Acc 0.8644
# Epoch 0080 | Time 0.324 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8651
# Epoch 0081 | Time 0.331 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8651
# Epoch 0082 | Time 0.321 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8649
# Epoch 0083 | Time 0.329 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8655
# Epoch 0084 | Time 0.306 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8658
# Epoch 0085 | Time 0.309 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8638
# Epoch 0086 | Time 0.311 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8648
# Epoch 0087 | Time 0.350 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8633
# Epoch 0088 | Time 0.342 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8649
# Epoch 0089 | Time 0.387 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8635
# Epoch 0090 | Time 0.311 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8658
# Epoch 0091 | Time 0.392 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8647
# Epoch 0092 | Time 0.331 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8653
# Epoch 0093 | Time 0.318 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8641
# Epoch 0094 | Time 0.318 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8651
# Epoch 0095 | Time 0.336 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8639
# Epoch 0096 | Time 0.322 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8642
# Epoch 0097 | Time 0.322 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8649
# Epoch 0098 | Time 0.326 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8638
# Epoch 0099 | Time 0.309 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8642
# Epoch 0100 | Time 0.318 (0.060) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8633
# Epoch 0101 | Time 0.327 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8645
# Epoch 0102 | Time 0.306 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8645
# Epoch 0103 | Time 0.327 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8642
# Epoch 0104 | Time 0.332 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8637
# Epoch 0105 | Time 0.319 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8642
# Epoch 0106 | Time 0.310 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8644
# Epoch 0107 | Time 0.335 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8644
# Epoch 0108 | Time 0.328 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8643
# Epoch 0109 | Time 0.317 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8646
# Epoch 0110 | Time 0.337 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8642
# Epoch 0111 | Time 0.323 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8643
# Epoch 0112 | Time 0.315 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8643
# Epoch 0113 | Time 0.378 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8642
# Epoch 0114 | Time 0.354 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8640
# Epoch 0115 | Time 0.395 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8640
# Epoch 0116 | Time 0.331 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8644
# Epoch 0117 | Time 0.318 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8647
# Epoch 0118 | Time 0.332 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8644
# Epoch 0119 | Time 0.344 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8644
# Epoch 0120 | Time 0.353 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8648
# Epoch 0121 | Time 0.324 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8646
# Epoch 0122 | Time 0.347 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8647
# Epoch 0123 | Time 0.332 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8648
# Epoch 0124 | Time 0.355 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8647
# Epoch 0125 | Time 0.331 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8643
# Epoch 0126 | Time 0.369 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8647
# Epoch 0127 | Time 0.323 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8647
# Epoch 0128 | Time 0.322 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8644
# Epoch 0129 | Time 0.353 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8648
# Epoch 0130 | Time 0.342 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8647
# Epoch 0131 | Time 0.312 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8646
# Epoch 0132 | Time 0.342 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8643
# Epoch 0133 | Time 0.308 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8639
# Epoch 0134 | Time 0.389 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8643
# Epoch 0135 | Time 0.313 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8646
# Epoch 0136 | Time 0.335 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9998 | Test Acc 0.8642
# Epoch 0137 | Time 0.320 (0.060) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8643
# Epoch 0138 | Time 0.315 (0.061) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8642
# Epoch 0139 | Time 0.318 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8642
# Epoch 0140 | Time 0.328 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8641
# Epoch 0141 | Time 0.318 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8640
# Epoch 0142 | Time 0.312 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8640
# Epoch 0143 | Time 0.330 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8640
# Epoch 0144 | Time 0.313 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8641
# Epoch 0145 | Time 0.311 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8640
# Epoch 0146 | Time 0.319 (0.060) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8643
# Epoch 0147 | Time 0.347 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8640
# Epoch 0148 | Time 0.360 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8641
# Epoch 0149 | Time 0.315 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8640
# Epoch 0150 | Time 0.329 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8640
# Epoch 0151 | Time 0.362 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8642
# Epoch 0152 | Time 0.328 (0.062) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8642
# Epoch 0153 | Time 0.353 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8642
# Epoch 0154 | Time 0.340 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8641
# Epoch 0155 | Time 0.349 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8641
# Epoch 0156 | Time 0.324 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8640
# Epoch 0157 | Time 0.314 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8641
# Epoch 0158 | Time 0.334 (0.059) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8641
# Epoch 0159 | Time 0.361 (0.058) | NFE-F 0.0 | NFE-B 0.0 | Train Acc 0.9999 | Test Acc 0.8642

# %%
65*64*9

# %%
torch.round(x/0.001).item()
# Out:
# 346.0

# %%
int(x/0.1)
# Out:
# 9
